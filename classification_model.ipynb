# %% [markdown]
# ## Data Preprocessing

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test images/virat_kohli/2Q__ (2).jpg')
img.shape
# Out:
# (258, 195, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/data/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/data/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 65,  37, 107, 107]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (65, 37, 107, 107)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/lionel_messi/liomessi (1).jpg')
plt.imshow(cropped_image)

# %%
path_to_data = "./test_images/"
path_to_cr_data = "./test_images/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./test_images/cropped',
#  './test_images/lionel_messi',
#  './test_images/ms_dhoni',
#  './test_images/roger federer',
#  './test_images/ronaldo',
#  './test_images/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# cropped
# lionel_messi
# Generating cropped images in folder:  ./test_images/cropped/lionel_messi
# ms_dhoni
# Generating cropped images in folder:  ./test_images/cropped/ms_dhoni
# roger federer
# Generating cropped images in folder:  ./test_images/cropped/roger federer
# ronaldo
# Generating cropped images in folder:  ./test_images/cropped/ronaldo
# virat_kohli
# Generating cropped images in folder:  ./test_images/cropped/virat_kohli

# %%
celebrity_file_names_dict
# Out:
# {'cropped': [],
#  'lionel_messi': ['./test_images/cropped/lionel_messi/lionel_messi1.png',
#   './test_images/cropped/lionel_messi/lionel_messi2.png',
#   './test_images/cropped/lionel_messi/lionel_messi3.png',
#   './test_images/cropped/lionel_messi/lionel_messi4.png',
#   './test_images/cropped/lionel_messi/lionel_messi5.png',
#   './test_images/cropped/lionel_messi/lionel_messi6.png',
#   './test_images/cropped/lionel_messi/lionel_messi7.png',
#   './test_images/cropped/lionel_messi/lionel_messi8.png',
#   './test_images/cropped/lionel_messi/lionel_messi9.png',
#   './test_images/cropped/lionel_messi/lionel_messi10.png',
#   './test_images/cropped/lionel_messi/lionel_messi11.png',
#   './test_images/cropped/lionel_messi/lionel_messi12.png',
#   './test_images/cropped/lionel_messi/lionel_messi13.png',
#   './test_images/cropped/lionel_messi/lionel_messi14.png',
#   './test_images/cropped/lionel_messi/lionel_messi15.png',
#   './test_images/cropped/lionel_messi/lionel_messi16.png',
#   './test_images/cropped/lionel_messi/lionel_messi17.png',
#   './test_images/cropped/lionel_messi/lionel_messi18.png'],
#  'ms_dhoni': ['./test_images/cropped/ms_dhoni/ms_dhoni1.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni2.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni3.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni4.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni5.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni6.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni7.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni8.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni9.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni10.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni11.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni12.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni13.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni14.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni15.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni16.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni17.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni18.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni19.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni20.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni21.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni22.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni23.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni24.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni25.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni26.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni27.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni28.png',
#   './test_images/cropped/ms_dhoni/ms_dhoni29.png'],
#  'roger federer': ['./test_images/cropped/roger federer/roger federer1.png',
#   './test_images/cropped/roger federer/roger federer2.png',
#   './test_images/cropped/roger federer/roger federer3.png',
#   './test_images/cropped/roger federer/roger federer4.png',
#   './test_images/cropped/roger federer/roger federer5.png',
#   './test_images/cropped/roger federer/roger federer6.png',
#   './test_images/cropped/roger federer/roger federer7.png',
#   './test_images/cropped/roger federer/roger federer8.png',
#   './test_images/cropped/roger federer/roger federer9.png',
#   './test_images/cropped/roger federer/roger federer10.png',
#   './test_images/cropped/roger federer/roger federer11.png',
#   './test_images/cropped/roger federer/roger federer12.png',
#   './test_images/cropped/roger federer/roger federer13.png',
#   './test_images/cropped/roger federer/roger federer14.png'],
#  'ronaldo': ['./test_images/cropped/ronaldo/ronaldo1.png',
#   './test_images/cropped/ronaldo/ronaldo2.png',
#   './test_images/cropped/ronaldo/ronaldo3.png',
#   './test_images/cropped/ronaldo/ronaldo4.png',
#   './test_images/cropped/ronaldo/ronaldo5.png',
#   './test_images/cropped/ronaldo/ronaldo6.png',
#   './test_images/cropped/ronaldo/ronaldo7.png',
#   './test_images/cropped/ronaldo/ronaldo8.png',
#   './test_images/cropped/ronaldo/ronaldo9.png',
#   './test_images/cropped/ronaldo/ronaldo10.png',
#   './test_images/cropped/ronaldo/ronaldo11.png',
#   './test_images/cropped/ronaldo/ronaldo12.png',
#   './test_images/cropped/ronaldo/ronaldo13.png',
#   './test_images/cropped/ronaldo/ronaldo14.png',
#   './test_images/cropped/ronaldo/ronaldo15.png',
#   './test_images/cropped/ronaldo/ronaldo16.png',
#   './test_images/cropped/ronaldo/ronaldo17.png',
#   './test_images/cropped/ronaldo/ronaldo18.png',
#   './test_images/cropped/ronaldo/ronaldo19.png',
#   './test_images/cropped/ronaldo/ronaldo20.png',
#   './test_images/cropped/ronaldo/ronaldo21.png',
#   './test_images/cropped/ronaldo/ronaldo22.png',
#   './test_images/cropped/ronaldo/ronaldo23.png',
#   './test_images/cropped/ronaldo/ronaldo24.png',
#   './test_images/cropped/ronaldo/ronaldo25.png',
#   './test_images/cropped/ronaldo/ronaldo26.png'],
#  'virat_kohli': ['./test_images/cropped/virat_kohli/virat_kohli1.png',
#   './test_images/cropped/virat_kohli/virat_kohli2.png',
#   './test_images/cropped/virat_kohli/virat_kohli3.png',
#   './test_images/cropped/virat_kohli/virat_kohli4.png',
#   './test_images/cropped/virat_kohli/virat_kohli5.png',
#   './test_images/cropped/virat_kohli/virat_kohli6.png',
#   './test_images/cropped/virat_kohli/virat_kohli7.png',
#   './test_images/cropped/virat_kohli/virat_kohli8.png',
#   './test_images/cropped/virat_kohli/virat_kohli9.png',
#   './test_images/cropped/virat_kohli/virat_kohli10.png',
#   './test_images/cropped/virat_kohli/virat_kohli11.png',
#   './test_images/cropped/virat_kohli/virat_kohli12.png',
#   './test_images/cropped/virat_kohli/virat_kohli13.png',
#   './test_images/cropped/virat_kohli/virat_kohli14.png',
#   './test_images/cropped/virat_kohli/virat_kohli15.png',
#   './test_images/cropped/virat_kohli/virat_kohli16.png',
#   './test_images/cropped/virat_kohli/virat_kohli17.png',
#   './test_images/cropped/virat_kohli/virat_kohli18.png',
#   './test_images/cropped/virat_kohli/virat_kohli19.png',
#   './test_images/cropped/virat_kohli/virat_kohli20.png',
#   './test_images/cropped/virat_kohli/virat_kohli21.png',
#   './test_images/cropped/virat_kohli/virat_kohli22.png',
#   './test_images/cropped/virat_kohli/virat_kohli23.png',
#   './test_images/cropped/virat_kohli/virat_kohli24.png',
#   './test_images/cropped/virat_kohli/virat_kohli25.png',
#   './test_images/cropped/virat_kohli/virat_kohli26.png',
#   './test_images/cropped/virat_kohli/virat_kohli27.png',
#   './test_images/cropped/virat_kohli/virat_kohli28.png',
#   './test_images/cropped/virat_kohli/virat_kohli29.png',
#   './test_images/cropped/virat_kohli/virat_kohli30.png',
#   './test_images/cropped/virat_kohli/virat_kohli31.png',
#   './test_images/cropped/virat_kohli/virat_kohli32.png',
#   './test_images/cropped/virat_kohli/virat_kohli33.png',
#   './test_images/cropped/virat_kohli/virat_kohli34.png',
#   './test_images/cropped/virat_kohli/virat_kohli35.png',
#   './test_images/cropped/virat_kohli/virat_kohli36.png',
#   './test_images/cropped/virat_kohli/virat_kohli37.png',
#   './test_images/cropped/virat_kohli/virat_kohli38.png',
#   './test_images/cropped/virat_kohli/virat_kohli39.png']}

# %% [markdown]
# ## Wavelet Transformation

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'lionel_messi': ['./test_images/cropped/lionel_messi\\lionel_messi1.png',
#   './test_images/cropped/lionel_messi\\lionel_messi10.png',
#   './test_images/cropped/lionel_messi\\lionel_messi11.png',
#   './test_images/cropped/lionel_messi\\lionel_messi12.png',
#   './test_images/cropped/lionel_messi\\lionel_messi13.png',
#   './test_images/cropped/lionel_messi\\lionel_messi14.png',
#   './test_images/cropped/lionel_messi\\lionel_messi15.png',
#   './test_images/cropped/lionel_messi\\lionel_messi16.png',
#   './test_images/cropped/lionel_messi\\lionel_messi17.png',
#   './test_images/cropped/lionel_messi\\lionel_messi18.png',
#   './test_images/cropped/lionel_messi\\lionel_messi2.png',
#   './test_images/cropped/lionel_messi\\lionel_messi3.png',
#   './test_images/cropped/lionel_messi\\lionel_messi4.png',
#   './test_images/cropped/lionel_messi\\lionel_messi5.png',
#   './test_images/cropped/lionel_messi\\lionel_messi6.png',
#   './test_images/cropped/lionel_messi\\lionel_messi7.png',
#   './test_images/cropped/lionel_messi\\lionel_messi8.png',
#   './test_images/cropped/lionel_messi\\lionel_messi9.png'],
#  'ms_dhoni': ['./test_images/cropped/ms_dhoni\\ms_dhoni1.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni10.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni11.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni12.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni13.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni14.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni15.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni16.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni17.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni18.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni19.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni2.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni20.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni21.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni22.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni23.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni24.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni25.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni26.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni27.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni28.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni29.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni3.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni4.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni5.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni6.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni7.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni8.png',
#   './test_images/cropped/ms_dhoni\\ms_dhoni9.png'],
#  'roger federer': ['./test_images/cropped/roger federer\\roger federer1.png',
#   './test_images/cropped/roger federer\\roger federer10.png',
#   './test_images/cropped/roger federer\\roger federer11.png',
#   './test_images/cropped/roger federer\\roger federer12.png',
#   './test_images/cropped/roger federer\\roger federer13.png',
#   './test_images/cropped/roger federer\\roger federer14.png',
#   './test_images/cropped/roger federer\\roger federer2.png',
#   './test_images/cropped/roger federer\\roger federer3.png',
#   './test_images/cropped/roger federer\\roger federer4.png',
#   './test_images/cropped/roger federer\\roger federer5.png',
#   './test_images/cropped/roger federer\\roger federer6.png',
#   './test_images/cropped/roger federer\\roger federer7.png',
#   './test_images/cropped/roger federer\\roger federer8.png',
#   './test_images/cropped/roger federer\\roger federer9.png'],
#  'ronaldo': ['./test_images/cropped/ronaldo\\ronaldo1.png',
#   './test_images/cropped/ronaldo\\ronaldo10.png',
#   './test_images/cropped/ronaldo\\ronaldo11.png',
#   './test_images/cropped/ronaldo\\ronaldo12.png',
#   './test_images/cropped/ronaldo\\ronaldo13.png',
#   './test_images/cropped/ronaldo\\ronaldo14.png',
#   './test_images/cropped/ronaldo\\ronaldo15.png',
#   './test_images/cropped/ronaldo\\ronaldo16.png',
#   './test_images/cropped/ronaldo\\ronaldo17.png',
#   './test_images/cropped/ronaldo\\ronaldo18.png',
#   './test_images/cropped/ronaldo\\ronaldo19.png',
#   './test_images/cropped/ronaldo\\ronaldo2.png',
#   './test_images/cropped/ronaldo\\ronaldo20.png',
#   './test_images/cropped/ronaldo\\ronaldo21.png',
#   './test_images/cropped/ronaldo\\ronaldo22.png',
#   './test_images/cropped/ronaldo\\ronaldo23.png',
#   './test_images/cropped/ronaldo\\ronaldo24.png',
#   './test_images/cropped/ronaldo\\ronaldo25.png',
#   './test_images/cropped/ronaldo\\ronaldo26.png',
#   './test_images/cropped/ronaldo\\ronaldo3.png',
#   './test_images/cropped/ronaldo\\ronaldo4.png',
#   './test_images/cropped/ronaldo\\ronaldo5.png',
#   './test_images/cropped/ronaldo\\ronaldo6.png',
#   './test_images/cropped/ronaldo\\ronaldo7.png',
#   './test_images/cropped/ronaldo\\ronaldo8.png',
#   './test_images/cropped/ronaldo\\ronaldo9.png'],
#  'virat_kohli': ['./test_images/cropped/virat_kohli\\virat_kohli1.png',
#   './test_images/cropped/virat_kohli\\virat_kohli10.png',
#   './test_images/cropped/virat_kohli\\virat_kohli11.png',
#   './test_images/cropped/virat_kohli\\virat_kohli12.png',
#   './test_images/cropped/virat_kohli\\virat_kohli13.png',
#   './test_images/cropped/virat_kohli\\virat_kohli14.png',
#   './test_images/cropped/virat_kohli\\virat_kohli15.png',
#   './test_images/cropped/virat_kohli\\virat_kohli16.png',
#   './test_images/cropped/virat_kohli\\virat_kohli17.png',
#   './test_images/cropped/virat_kohli\\virat_kohli18.png',
#   './test_images/cropped/virat_kohli\\virat_kohli19.png',
#   './test_images/cropped/virat_kohli\\virat_kohli2.png',
#   './test_images/cropped/virat_kohli\\virat_kohli20.png',
#   './test_images/cropped/virat_kohli\\virat_kohli21.png',
#   './test_images/cropped/virat_kohli\\virat_kohli22.png',
#   './test_images/cropped/virat_kohli\\virat_kohli23.png',
#   './test_images/cropped/virat_kohli\\virat_kohli24.png',
#   './test_images/cropped/virat_kohli\\virat_kohli25.png',
#   './test_images/cropped/virat_kohli\\virat_kohli26.png',
#   './test_images/cropped/virat_kohli\\virat_kohli27.png',
#   './test_images/cropped/virat_kohli\\virat_kohli28.png',
#   './test_images/cropped/virat_kohli\\virat_kohli29.png',
#   './test_images/cropped/virat_kohli\\virat_kohli3.png',
#   './test_images/cropped/virat_kohli\\virat_kohli30.png',
#   './test_images/cropped/virat_kohli\\virat_kohli31.png',
#   './test_images/cropped/virat_kohli\\virat_kohli32.png',
#   './test_images/cropped/virat_kohli\\virat_kohli33.png',
#   './test_images/cropped/virat_kohli\\virat_kohli34.png',
#   './test_images/cropped/virat_kohli\\virat_kohli35.png',
#   './test_images/cropped/virat_kohli\\virat_kohli36.png',
#   './test_images/cropped/virat_kohli\\virat_kohli37.png',
#   './test_images/cropped/virat_kohli\\virat_kohli38.png',
#   './test_images/cropped/virat_kohli\\virat_kohli39.png',
#   './test_images/cropped/virat_kohli\\virat_kohli4.png',
#   './test_images/cropped/virat_kohli\\virat_kohli5.png',
#   './test_images/cropped/virat_kohli\\virat_kohli6.png',
#   './test_images/cropped/virat_kohli\\virat_kohli7.png',
#   './test_images/cropped/virat_kohli\\virat_kohli8.png',
#   './test_images/cropped/virat_kohli\\virat_kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'lionel_messi': 0,
#  'ms_dhoni': 1,
#  'roger federer': 2,
#  'ronaldo': 3,
#  'virat_kohli': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
len(X)
# Out:
# 126

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (126, 4096)

# %%
X[0]
# Out:
# array([  5.,  10.,   9., ...,  52., 121., 220.])

# %%
len(y)
# Out:
# 126

# %% [markdown]
#   <h2><b> MODEL TRAINING</b></h1>

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.71875

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         6
#            1       0.58      1.00      0.74         7
#            2       0.00      0.00      0.00         4
#            3       0.57      0.67      0.62         6
#            4       0.90      1.00      0.95         9
#
#     accuracy                           0.72        32
#    macro avg       0.61      0.63      0.59        32
# weighted avg       0.68      0.72      0.67        32
# C:\Users\Sanjay\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
len(X_test)
# Out:
# 32

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,3,5,10,100],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,3,8]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\Users\Sanjay\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\Sanjay\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\Sanjay\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
#                  model  best_score  \
# 0                  svm    0.617021
# 1        random_forest    0.574468
# 2  logistic_regression    0.585106
#
#                                    best_params
# 0          {'svc__C': 3, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 8}
# 2                 {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('svc',
#                   SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#                       decision_function_shape='ovr', degree=3, gamma='auto',
#                       kernel='rbf', max_iter=-1, probability=True,
#                       random_state=None, shrinking=True, tol=0.001,
#                       verbose=False))],
#           verbose=False), 'random_forest': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(bootstrap=True, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features='auto',
#                                          max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=10, n_jobs=None,
#                                          oob_score=False, random_state=None,
#                                          verbose=0, warm_start=False))],
#           verbose=False), 'logistic_regression': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('logisticregression',
#                   LogisticRegression(C=1, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=100,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=None,
#                                      solver='liblinear', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False)}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.71875

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5625

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.78125

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[4, 1, 0, 1, 0],
#        [0, 6, 0, 1, 0],
#        [0, 1, 3, 0, 0],
#        [1, 2, 0, 3, 0],
#        [0, 0, 0, 0, 9]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'lionel_messi': 0,
#  'ms_dhoni': 1,
#  'roger federer': 2,
#  'ronaldo': 3,
#  'virat_kohli': 4}

# %% [markdown]
# > ### Save Model

# %%
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %% [markdown]
# > ### Save Class Dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
